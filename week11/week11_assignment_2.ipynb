# %% [markdown]
# <a href="https://colab.research.google.com/github/vsaathwika0904/hds5210-2023/blob/main/week11/week11_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 11 Assignment
#
#
# Please do the programming exercise and verify that your code works using the tests, then think about your final project and fill out the questions in the second part.
#
# ---
# ---

# %% [markdown]
# ### 47.1: Filtering and summarizing data
#
# For this work, you'll find a data file in `https://hds5210-data.s3.amazonaws.com/complications_all.csv`.
#
# Read in the data file and create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# Then aggregate that data by hospital into a variable named `mo_summary`.  There are some key fields that we want to summarize:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
#
# You do not need to create your code in the form of a function, just make sure your variable names match what I've described above so the tests work.

# %%
import pandas as pd
# This is just to show you the name to use for the variable you need to create for this step to pass.
all_hospitals = pd.read_csv('/content/complications_all.csv')

# %%
# Do you work here and in as many cells as you need to create a variable called `mo_summary` that matches the requirements
import pandas as pd

# Load the hospital data for all states
all_hospitals = pd.read_csv('/content/complications_all.csv')

# Filter for hospitals in Missouri and exclude rows where 'Denominator' is 'Not Available'
missouri_hospitals = all_hospitals[all_hospitals['State'] == 'MO']
missouri_hospitals = mo_hospitals[mo_hospitals['Denominator'] != 'Not Available']

# Create an empty DataFrame for the summary
summary_dataframe = pd.DataFrame({})

# Filter hospitals with the name 'hospital'
missouri_hospitals[missouri_hospitals['Facility Name'] == 'hospital']

# Convert date columns to datetime and 'Denominator' column to numeric
missouri_hospitals['start_date'] = pd.to_datetime(missouri_hospitals['Start Date'])
missouri_hospitals['end_date'] = pd.to_datetime(missouri_hospitals['End Date'])
missouri_hospitals['Denominator'] = pd.to_numeric(missouri_hospitals['Denominator'])

# Initialize lists to store data
hospital_names = []
hospital_data = []

# Process data for each unique hospital
for hospital in missouri_hospitals['Facility Name'].unique():
    hospital_subset = missouri_hospitals[missouri_hospitals['Facility Name'] == hospital]
    start_date = hospital_subset['Start Date'].min()
    end_date = hospital_subset['End Date'].max()
    total_denominator = sum(hospital_subset['Denominator'])
    entry = [start_date, end_date, total_denominator]

    hospital_data.append(entry)
    hospital_data_index = ['start_date', 'end_date', 'total_denominator']
    hospital_names.append(hospital)

# Create the summary DataFrame
summary_dataframe = pd.DataFrame(hospital_data, index=hospital_names, columns=hospital_data_index)

# Convert date columns to datetime format
summary_dataframe['start_date'] = pd.to_datetime(summary_dataframe['start_date'])
summary_dataframe['end_date'] = pd.to_datetime(summary_dataframe['end_date'])

# Display the final summary DataFrame
summary_dataframe
# Out:
#                                          start_date   end_date  \
# MERCY HOSPITAL JOPLIN                    2015-04-01 2018-06-30
# COOPER COUNTY COMMUNITY HOSPITAL         2015-07-01 2018-06-30
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 2015-04-01 2018-06-30
# MOSAIC LIFE CARE AT ST JOSEPH            2015-04-01 2018-06-30
# BOTHWELL REGIONAL HEALTH CENTER          2015-04-01 2018-06-30
# ...                                             ...        ...
# I-70 COMMUNITY HOSPITAL                  2015-07-01 2018-06-30
# MERCY ST FRANCIS HOSPITAL                2015-07-01 2018-06-30
# IRON COUNTY MEDICAL CENTER               2015-07-01 2018-06-30
# MISSOURI BAPTIST SULLIVAN HOSPITAL       2015-07-01 2018-06-30
# MERCY HOSPITAL CARTHAGE                  2015-07-01 2018-06-30
#
#                                           total_denominator
# MERCY HOSPITAL JOPLIN                                 29977
# COOPER COUNTY COMMUNITY HOSPITAL                        697
# ...

# %%
assert(summary_dataframe['total_denominator'].sum() == 1766908)
assert(summary_dataframe['start_date'].min() == pd.Timestamp(2015,4,1))
assert(summary_dataframe['end_date'].max() == pd.Timestamp(2018,6,30))
assert(summary_dataframe.shape == (108,3))
assert(summary_dataframe.loc['BARNES JEWISH HOSPITAL'].total_denominator == 131313)
assert(summary_dataframe.loc['BOONE HOSPITAL CENTER'].total_denominator == 63099)

# %% [markdown]
# ---
#
# ### 47.2 Planning your final project
#
# You should be thinking about the things we've been learning and how you can apply them to your final project.  Use the rubric to help guid your thinking and then answer the questions below.  This is meant as a guide to help you think through what you will do.

# %% [markdown]
# #### A) Data Access
#
# Your project should include data from at least three distinct types of sources.  For example: AWS S3, Relational Databases, Internet, Web Services, local files.  List what data sources you're planning to use.

# %% [markdown]
# I will collect my dataset from internet sources like usgs.gov, data.gov, and kaggle.

# %% [markdown]
# #### B. Data Formats
#
# Your project should include data that comes in different file formats.  For example: HL7, EDI, HTML, CSV, Excel, JSON, XML.  List what data formats you're planning to use.

# %% [markdown]
# I will use HTML, CSV, Excel or JSON as the format of my data.

# %% [markdown]
# #### C. Objective
#
# What purpose would your project serve in a real work setting?  Take a couple of paragraphs to write down why this is an interesting product.

# %% [markdown]
# The source of machine learning and visualization in managing neurological disorders is a remarkable development. Machine learning can be helpful in creating personalised treatment plans, early detection of diseases and alignment according to genetic profiles. On the other hand, visualization offers a straightforward way of representing complex information. If used in conjunction, machine learning and visualization can enable a collaborative world approach to neuro-health, making it easier to treat neurological illnesses based on a person’s need and conduct remote monitoring during neuro-rehabilitation.

# %% [markdown]
# ---
#
#
#
# ## Submit your work via GitHub as normal
