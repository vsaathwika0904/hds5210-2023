# %% [markdown]
# <a href="https://colab.research.google.com/github/vsaathwika0904/hds5210-2023/blob/main/week13/week13_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd

# Read the data from the CSV file
df = pd.read_csv('/content/autism_screening.csv')

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
import pandas as pd

data_path = '/content/autism_screening.csv'
df = pd.read_csv(data_path)
unique_counts = df.nunique()
max_unique_column = unique_counts.idxmax()
print("Number of unique values in each column:")
print(unique_counts)
print("\nColumn with the greatest number of distinct values:")
print(f"{max_unique_column} with {unique_counts[max_unique_column]} unique values.")
# Out:
# Number of unique values in each column:
# A1_Score            2
# A2_Score            2
# A3_Score            2
# A4_Score            2
# A5_Score            2
# A6_Score            2
# A7_Score            2
# A8_Score            2
# A9_Score            2
# A10_Score           2
# age                46
# gender              2
# ethnicity          12
# jundice             2
# austim              2
# contry_of_res      67
# used_app_before     2
# result             11
# age_desc            1
# relation            6
# Class/ASD           2
# dtype: int64
#
# Column with the greatest number of distinct values:
# contry_of_res with 67 unique values.

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
import pandas as pd
data_path = '/content/autism_screening.csv'
df = pd.read_csv(data_path)
constant_columns = df.columns[df.nunique() == 1]
print("Columns where the value is the same for every row:")
print(constant_columns)
# Out:
# Columns where the value is the same for every row:
# Index(['age_desc'], dtype='object')

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
#Here i created a histogram that shows Distribution of values for age. Most of the age group lies from 0-50
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/autism_screening.csv', low_memory=False)
plt.hist(data['age'], bins=10, edgecolor='black')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Distribution of values for age')
plt.show()

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data_path = '/content/autism_screening.csv'

# Read the dataset into a pandas DataFrame
df = pd.read_csv(data_path)

# Check if the 'contry_of_res' and 'A1_Score' columns exist in the DataFrame
required_columns = ['contry_of_res', 'A1_Score']
if not all(column in df.columns for column in required_columns):
    missing_columns = ', '.join(set(required_columns) - set(df.columns))
    print(f"Error: Columns {missing_columns} not found in the dataset.")
else:
    # Create a box plot of screening scores by education level using Seaborn
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='contry_of_res', y='A1_Score', data=df, palette='viridis')

    # Add labels and title
    plt.xlabel('contry_of_res')
    plt.ylabel('Screening Score')
    plt.title('Box Plot of Screening Scores by contry_of_res')

    # Show the plot
    plt.show()

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
